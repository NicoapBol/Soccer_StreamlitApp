# %%
from statsbombpy import sb
import pandas as pd

# %%
df = sb.competitions()
df
# Out:
# /Users/nicoap/micromamba/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id   country_name        competition_name  \
# 0                9        281        Germany           1. Bundesliga
# 1                9         27        Germany           1. Bundesliga
# 2             1267        107         Africa  African Cup of Nations
# 3               16          4         Europe        Champions League
# 4               16          1         Europe        Champions League
# ..             ...        ...            ...                     ...
# 69              55         43         Europe               UEFA Euro
# 70              35         75         Europe      UEFA Europa League
# 71              53        106         Europe       UEFA Women's Euro
# 72              72        107  International       Women's World Cup
# ...

# %%
df = sb.competitions()
df = df[df['country_name']=="International"]
df
# Out:
# /Users/nicoap/micromamba/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id   country_name    competition_name  \
# 28            1470        274  International  FIFA U20 World Cup
# 29              43        106  International      FIFA World Cup
# 30              43          3  International      FIFA World Cup
# 31              43         55  International      FIFA World Cup
# 32              43         54  International      FIFA World Cup
# 33              43         51  International      FIFA World Cup
# 34              43        272  International      FIFA World Cup
# 35              43        270  International      FIFA World Cup
# 36              43        269  International      FIFA World Cup
# 72              72        107  International   Women's World Cup
# 73              72         30  International   Women's World Cup
#
# ...

# %%
events = sb.competition_events(
    country="International",
    division= "FIFA World Cup",
    season="2022",
    gender="male"
)

grouped_events = sb.competition_events(
    country="International",
    division= "FIFA World Cup",
    season="2022",
    split=True
)
# Out:
# /Users/nicoap/micromamba/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/nicoap/micromamba/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/nicoap/micromamba/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/nicoap/micromamba/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/nicoap/micromamba/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# ...

# %%
events = grouped_events["shots"]  # This is a list
events = pd.DataFrame(events)  # Convert to DataFrame
events = events[events["team"] == "Argentina"]

# %%
matches=sb.matches(competition_id=43, season_id=106)

# %%
matches = pd.DataFrame(matches)
matches = matches.drop(
    [        "referee", "home_managers", "away_managers", "data_version",
        "shot_fidelity_version", "xy_fidelity_version", "match_status_360",
        "last_updated", "last_updated_360", "match_week"
    ], 
    axis=1
)

matches.columns
# Out:
# Index(['match_id', 'match_date', 'kick_off', 'competition', 'season',
#        'home_team', 'away_team', 'home_score', 'away_score', 'match_status',
#        'competition_stage', 'stadium'],
#       dtype='object')

# %%
matches = matches[(matches["home_team"] == "Argentina") | (matches["away_team"] == "Argentina")]
matches["match_info"] = matches["home_team"] + " Vs. " + matches["away_team"] + " " + "(" + matches["match_date"] + ")"
matches["outcome"] = matches["home_team"] +" "+ matches["home_score"].astype(str) + " - " + matches["away_team"]+ " " + matches["away_score"].astype(str)

# %%
matches.to_csv("world_cup22_matches.csv")

# %%
events["penalty"] = events["shot_type"].apply(lambda x: "yes" if x == "penalty" else "no")
events[['X', 'Y']] = pd.DataFrame(events['location'].tolist(), index=events.index)
events["xG"] = events['shot_statsbomb_xg']
events["result"] = events['shot_outcome']

# %%
events = events.merge(matches, on="match_id", how="left")
events.to_csv("arg_eventsWC22.csv", index=False, encoding="utf-8-sig")
